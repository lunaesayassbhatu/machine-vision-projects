# %%
# !pip install transformers torch torchvision
# !pip install accelerate
# !pip install opencv-python matplotlib pillow
# Out:
# Requirement already satisfied: transformers in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (5.3.0)
# Requirement already satisfied: torch in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (2.11.0)
# Requirement already satisfied: torchvision in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (0.26.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from transformers) (1.7.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from transformers) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: setuptools<82 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from torch) (80.10.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Requirement already satisfied: accelerate in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (1.13.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from accelerate) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from accelerate) (7.2.1)
# Requirement already satisfied: pyyaml in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from accelerate) (2.11.0)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from accelerate) (1.7.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.3)
# Requirement already satisfied: typer in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: anyio in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (4.12.1)
# Requirement already satisfied: certifi in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (1.0.9)
# Requirement already satisfied: idna in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (0.16.0)
# Requirement already satisfied: setuptools<82 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from torch>=2.0.0->accelerate) (80.10.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from tqdm>=4.42.1->huggingface_hub>=0.21.0->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from typer->huggingface_hub>=0.21.0->accelerate) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from typer->huggingface_hub>=0.21.0->accelerate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from typer->huggingface_hub>=0.21.0->accelerate) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from typer->huggingface_hub>=0.21.0->accelerate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (0.1.2)
# Requirement already satisfied: opencv-python in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (4.10.0)
# Requirement already satisfied: matplotlib in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (3.10.8)
# Requirement already satisfied: pillow in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from matplotlib) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sbhat\anaconda3\envs\vision\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from transformers import pipeline

# %%
# Put your image in the same folder as this notebook
# Change "your_image.jpg" to your actual image filename
filename = "your_image.jpg"

image = Image.open(filename).convert("RGB")
image = image.resize((512, 512))

plt.figure(figsize=(5,5))
plt.imshow(image)
plt.title("Input Image")
plt.axis("off")
plt.savefig("p2_input.png", dpi=150, bbox_inches='tight')
plt.show()
print("Image loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # Put your image in the same folder as this notebook
#       2 # Change "your_image.jpg" to your actual image filename
#       3 filename = "your_image.jpg"
# ----> 5 image = Image.open(filename).convert("RGB")
#       6 image = image.resize((512, 512))
#       8 plt.figure(figsize=(5,5))
#
# NameError: name 'Image' is not defined
